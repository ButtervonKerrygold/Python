# %% [markdown]
# # Labor 4: Strings

# %% [markdown]
# ## Teil 1: Vorübungen

# %% [markdown]
# ### Konkatenation: Wiederholung
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten.
#
# ▶ Führen Sie das Programm *anschließend* aus, um Ihre Annahme zu überprüfen.

# %%
text = 'Willkommen'
text = text + 'im'
text = text + 'Labor'
text = text + str(4)
text = text + '.'

print(text)

# %% [markdown]
# ### Konkatenation: Übung
#
# 🎯 Passen Sie das Skript so an, dass der Text `Willkommen im Labor 4` mit Leerzeichen ausgegeben wird.

# %%
text = 'Willkommen'
text = text + 'im'
text = text + 'Labor'
text = text + str(4)
text = text + '.'

print(text)

# %% [markdown]
# ### String-Multiplikation: Wiederholung
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten.
#
# ▶ Führen Sie das Programm *anschließend* aus, um Ihre Annahme zu überprüfen.
#
# 🎯 Setzen Sie einen **Breakpoint** in Zeile 1 und vollziehen Sie die Ausführung im **Debugger** nach. Achten Sie auf die Variablen `i` und `zeichen`.

# %%
text = 'Software'

i = 4
while i > 0:
    print(i * text)
    i = i - 1

# %% [markdown]
# ### String-Multiplikation: Übung
#
# 🎯 Schreiben Sie en Programm, das ein Wort von der Tastatur einliest und **fünf mal** hintereinander in einer Zeile ausgibt. Die Wörter sollten jeweils durch ein **Leerzeichen** getrennt sein.
#
# 👉 **Beispiel:** Die Eingabe `Software` sollte die Ausgabe `SoftwareSoftwareSoftwareSoftwareSoftware` erzeugen.

# %%
text = 'Software'
# text = input()

# %% [markdown]
# ### f-Strings: Wiederholung
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten. (Überprüfen sie danach Ihre Annahme.)
#
# 💭 Stellen Sie eine Vermutung an: Was bewirkt die Format-Angabe `:2`?

# %%
i = 1
while i <= 10:
    print(f'Labor {i:2}')
    i = i + 1

# %% [markdown]
# ### f-Strings: Übung
#
# 🎯 Passen Sie das folgende Skript so an, dass die Ausgabe folgendermaßen lautet:
# ```
#     1 * 1 =  1
#     2 * 2 =  4
#     3 * 3 =  9
#     4 * 4 = 16
#     5 * 5 = 25
# ```
#
# 💡 Nutzen Sie f-Strings.

# %%
i = 1
while i <= 5:
    print(i * i)
    i = i + 1

# %% [markdown]
# ### Indexing: Wiederholung
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten.
#
# ▶ Überprüfen Sie Ihre Annahme.

# %%
text = 'Labor 4'

print(text[1])
print(text[-1])

# %% [markdown]
# ### Indexing: Übung
#
# 🎯 Ändern Sie die Werte von `i1`, `i2` und `i3` _(und sonst nichts!)_, so dass die Ausgabe `THU` lautet.

# %%
text = 'HAUPTBAHNHOF'
i1 = 0
i2 = 7
i3 = -3

print(text[i1] + text[i2] + text[i3])

# %% [markdown]
# ### Schleifen über Strings: Wiederholung
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten. Überprüfen Sie Ihre Annahme.
#
# 🎯 Setzen Sie einen **Breakpoint** in Zeile 1 und vollziehen Sie die Ausführung im **Debugger** nach. Achten Sie auf die Variablen `i` und `zeichen`.

# %%
text = 'Labor 4'

i = 0
while i < 5:
    zeichen = text[i]
    print(zeichen)
    i = i + 1

# %% [markdown]
# ### Schleifen über Strings: Übung zum Verständnis
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten. Überprüfen Sie Ihre Annahme.
#
# 🎯 Vollziehen Sie die Ausführung im **Debugger** nach.

# %%
text = 'ELTA/BTO R-42'
text2 = ''

i = 1
while i < len(text):
    text2 = text2 + text[i]
    i = i + 2

print(text2)

# %% [markdown]
# ### Schleifen über Strings: Übung
#
# 🎯 Passen Sie das folgende Skript so an, dass die Ausgabe `L_A_B_O_R_4_` lautet.
#
# ❕ Verändern Sie **nicht** den Wert von `text`, sondern ändern Sie den Code innerhalb der Schleife.
#
# 👉 Eine *kleine* Änderung sollten genügen.

# %%
text = 'LABOR4'
nachricht = ''

i = 0
while i < len(text):
    nachricht = nachricht + text[i]
    i = i + 1

print(nachricht)

# %% [markdown]
# ### Slicing: Wiederholung
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten. (Überprüfen Sie Ihre Annahme.)

# %%
text = 'Software-Entwicklung'
print(text[:8])
print(text[9:])
print(text[1:4])

text2 = '<Labor 4>'
print(text2[1:-1])

# %% [markdown]
# ### Slicing: Übung
#
# 🎯 Hier ist etwas schief gegangen. Passen Sie das Skript so an, dass **je zehn Zeichen** von `text` in einer Zeile ausgegeben werden.
#
# 🎃 **Tipp:** Die Ausgabe sollte eine erkennbare ASCII-Grafik sein.

# %%
text = "    _         )\\     .'`--`'. /  ^  ^  \\\\ \\/\\/\\/ / '------' "

i = 0
while i < len(text):
    print(text[i:i+6])
    i = i + 6

# %% [markdown]
# ## Teil 2: Text-Art

# %% [markdown]
# ### Diagonaler Text
#
# 💭 *Überlegen* Sie zunächst, welche Ausgabe Sie von dem Programm erwarten. Überprüfen Sie Ihre Annahme.
#
# 👉 Probieren Sie auch andere Worte als `Software` aus.
#
# 🎯 Vollziehen Sie die Ausführung im **Debugger** nach.

# %%
wort = 'Software'
#wort = input()

i = 0
while i < len(wort):
    print(i * ' ' + wort[i])
    i = i + 1

# %% [markdown]
# ### Aufsteigender Text
#
# 🎯 Beachten Sie die Aufgabenstellung auf dem Laborblatt.
#
# 👉 Beispiel: Für ``Software` sollte die Ausgabe lauten:
#
# ```
#        S
#       o
#      f
#     t
#    w
#   a
#  r
# e
# ```

# %%
wort = 'Software'
#wort = input()

i = 0
while i < len(wort):
    print(i * ' ' + wort[i])
    i = i + 1

# %% [markdown]
# ### Wachsender Text
#
# 🎯 Beachten Sie die Aufgabenstellung auf dem Laborblatt.
#
# 👉 Beispiel: Für ``Software` sollte die Ausgabe lauten:
#
# ```
# S
# So
# Sof
# Soft
# Softw
# Softwa
# Softwar
# Software
# ```

# %%
wort = 'Software'
#wort = input()

i = 0
while i < len(wort):
    print(...)
    i = i + 1

# %% [markdown]
# ### Schrumpfender Text
#
# 🎯 Beachten Sie die Aufgabenstellung auf dem Laborblatt.
#
# 👉 **Beispiel:** Für ``Software` sollte die Ausgabe lauten:
#
# ```
# Software
#  oftware
#   ftware
#    tware
#     ware
#      are
#       re
#        e
# ```

# %%
wort = "SOTE1"
wort = "Software"

i = 1
while i <= len(wort):
    print(...)
    i = i + 1

# %% [markdown]
# ## Teil 3: Telefon-Nummern bereinigen

# %%
tel = "0731/965 37-351"
# tel = "+49 731 965 37 351"
# tel = input()

# Implementieren Sie den PAP
